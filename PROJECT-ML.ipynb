# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/drive/MyDrive/Python Data science/Churn_Modelling.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.ndim
# Out:
# 2

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.isna().any()
# Out:
# RowNumber          False
# CustomerId         False
# Surname            False
# CreditScore        False
# Geography          False
# Gender             False
# Age                False
# Tenure             False
# Balance            False
# NumOfProducts      False
# HasCrCard          False
# IsActiveMember     False
# EstimatedSalary    False
# Exited             False
# dtype: bool

# %%
#to check nulll values
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.describe() # to get overall Statistics of the dataset
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
#df.describe(include='all')

# %%
#unique
features=['CreditScore','Geography','Gender','Age','Tenure','Balance','NumOfProducts','HasCrCard','IsActiveMember','EstimatedSalary','Exited']

for i in features:
  print(df[i].unique(),i)
  print('--------------------')
# Out:
# [619 608 502 699 850 645 822 376 501 684 528 497 476 549 635 616 653 587
#  726 732 636 510 669 846 577 756 571 574 411 591 533 553 520 722 475 490
#  804 582 472 465 556 834 660 776 829 637 550 698 585 788 655 601 656 725
#  511 614 742 687 555 603 751 581 735 661 675 738 813 657 604 519 664 678
#  757 416 665 777 543 506 493 652 750 729 646 647 808 524 769 730 515 773
#  814 710 413 623 670 622 785 605 479 685 538 562 721 628 668 828 674 625
#  432 770 758 795 686 789 589 461 584 579 663 682 793 691 485 650 754 535
#  716 539 706 586 631 717 800 683 704 615 667 484 480 578 512 606 597 778
#  514 525 715 580 807 521 759 516 711 618 643 671 689 620 676 572 695 592
#  567 694 547 594 673 610 767 763 712 703 662 659 523 772 545 634 739 771
#  681 544 696 766 727 693 557 531 498 651 791 733 811 707 714 782 775 799
#  602 744 588 747 583 627 731 629 438 642 806 474 559 429 680 749 734 644
#  626 649 805 718 840 630 654 762 568 613 522 737 648 443 640 540 460 593
# ...

# %%
#value_counts
features=['CreditScore','Geography','Gender','Age','Tenure','Balance','NumOfProducts','HasCrCard','IsActiveMember','EstimatedSalary','Exited']

for i in features:

  print(df[i].value_counts(),i)
  print('--------------------')
# Out:
# CreditScore
# 850    233
# 678     63
# 655     54
# 705     53
# 667     53
#       ...
# 404      1
# 351      1
# 365      1
# 417      1
# 419      1
# Name: count, Length: 460, dtype: int64 CreditScore
# --------------------
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64 Geography
# --------------------
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64 Gender
# --------------------
# Age
# 37    478
# 38    477
# 35    474
# 36    456
# 34    447
#      ...
# 92      2
# 82      1
# 88      1
# 85      1
# 83      1
# Name: count, Length: 70, dtype: int64 Age
# --------------------
# Tenure
# 2     1048
# 1     1035
# 7     1028
# 8     1025
# 5     1012
# 3     1009
# 4      989
# 9      984
# 6      967
# 10     490
# 0      413
# Name: count, dtype: int64 Tenure
# --------------------
# Balance
# 0.00         3617
# 130170.82       2
# 105473.74       2
# 85304.27        1
# 159397.75       1
# ...

# %%
#Drop the columns which are not necessary
df = df.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df.shape
# Out:
# (10000, 11)

# %%
df.dtypes
# Out:
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df["Geography"].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df["Gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %% [markdown]
#  DATA VISUALIZATION

# %%
df["Exited"].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
#Pie  chart
import matplotlib.pyplot as plt


Exited = 2037
Not_Exited = 7963
labels = ['Not Exited', 'Exited']
plt.figure(figsize=(8,8))
plt.pie([Not_Exited, Exited], labels=labels, autopct='%1.3f%%', colors=['b', 'r'],startangle=90)
plt.title("Proportion of customer churned and retained")
plt.show()

# %% [markdown]
# From this we can a pie chart to visualize the proportion of customers who have exited (churned) and those who have not exited (retained) from a bank and also we can see that 20% of customers have been Exited and also 79%  are not Exited.

# %%
fig, axarr = plt.subplots(2, 2, figsize=(20, 12))

sns.countplot(x='Geography', hue='Exited', data=df, ax=axarr[0][0])
sns.countplot(x='Gender', hue='Exited', data=df, ax=axarr[0][1])
sns.countplot(x='Tenure', hue = 'Exited',data = df, ax=axarr[1][0])
sns.countplot(x='IsActiveMember', hue='Exited', data=df, ax=axarr[1][1])

plt.show()

# %% [markdown]
# from this we can visualize that:
#
# 1.Geography vs Exited:This plot shows how customer churn varies by geography (country or region).Majority of customers are from France, we can identify churn rates are higher in specific regions.
#
# 2.Gender vs Exited :This plot shows how customer churn differs between male and female customers.here we can observe that Male customers have churning than Female.
#
# 3.Tenure vs Exited:This plot shows the relationship between the length of time customers have been with the bank (tenure) and their likely to be churn.
# here we can understand that Majorty of customers have the tenure from 1 to 9
# and the churning rate is also high.
#
# 4.Is Active Member vs Exited:This plot shows the churn rates for active and inactive members.here we can see 1 has the more churn comapred to 0

# %%
fig, ax = plt.subplots(2, 2, figsize = (16, 10))
sns.boxplot(x = 'Exited', y = 'CreditScore', data = df, ax = ax[0][0])
sns.boxplot(x = 'Exited', y = 'Age', data = df, ax = ax[0][1])
sns.boxplot(x = 'Exited', y = 'Balance', data = df, ax = ax[1][0])
sns.boxplot(x = 'Exited', y = 'EstimatedSalary', data = df, ax = ax[1][1])

plt.show()

# %% [markdown]
# From this boxplot we can visualize :
#
# 1.Credit Score vs Exited: This box plot shows the distribution of credit scores for customers who have exited compared to those who have not, ie we can see there is no significant difference in credit score distribution which are churned or not.
#
# 2.Age vs Exited: This plot shows the age distribution of customers who have exited versus those who have not.customers who are older might likely to leave.
#
# 3.Balance vs Exited :This plot shows the distribution of account balances for customers who have exited versus those who have not.
# Here customers with certain balance are likely to be churned.
#
# 4.Estimated Salary vs. Exited :This plot illustrates the distribution of estimated salaries for customers who have exited compared to those who have not.

# %% [markdown]
# Convert categorical variables into Numeric

# %%
#LabelEncoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
list=['Geography','Gender']
for i in list:
  df[i]=le.fit_transform(df[i])
df
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619          0       0   42       2       0.00              1
# 1             608          2       0   41       1   83807.86              1
# 2             502          0       0   42       8  159660.80              3
# 3             699          0       0   39       1       0.00              2
# 4             850          2       0   43       2  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 9995          771          0       1   39       5       0.00              2
# 9996          516          0       1   35      10   57369.61              1
# 9997          709          0       0   36       7       0.00              1
# 9998          772          1       1   42       3   75075.31              2
# 9999          792          0       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %% [markdown]
# Here the value indicates:
#
# female=0, male=1
#
# France=0,germany=1,Spain=2

# %%
cor_mtx=df.corr()['Exited']
cor_mtx
# Out:
# CreditScore       -0.027094
# Geography          0.035943
# Gender            -0.106512
# Age                0.285323
# Tenure            -0.014001
# Balance            0.118533
# NumOfProducts     -0.047820
# HasCrCard         -0.007138
# IsActiveMember    -0.156128
# EstimatedSalary    0.012097
# Exited             1.000000
# Name: Exited, dtype: float64

# %% [markdown]
# Visualizing the correlation through Heatmap

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# split data into x and y

# %%
x=df.drop('Exited',axis=1)
y=df['Exited']

# %% [markdown]
# spliting the dataset into training set and testing set

# %%
#train_test_split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=20)

# %%
#Standardization
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
x_train
# Out:
# array([[ 1.34111823, -0.91036007, -1.08948952, ..., -1.55666057,
#          0.96801137, -1.45550088],
#        [-1.4670728 , -0.91036007,  0.91786105, ...,  0.6424008 ,
#          0.96801137, -0.24201773],
#        [-0.19155746, -0.91036007, -1.08948952, ..., -1.55666057,
#         -1.03304572, -1.1930393 ],
#        ...,
#        [ 0.5079187 ,  0.29461686, -1.08948952, ...,  0.6424008 ,
#          0.96801137,  0.98520155],
#        [-2.25912668, -0.91036007,  0.91786105, ...,  0.6424008 ,
#         -1.03304572, -0.06368086],
#        [-0.78816947,  1.49959379,  0.91786105, ..., -1.55666057,
#          0.96801137,  0.98536606]])

# %% [markdown]
# MODEL CREATION

# %% [markdown]
# 1)KNN ALGORITHM

# %%
from sklearn.neighbors import KNeighborsClassifier
Knn=KNeighborsClassifier(n_neighbors=5)
Knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred1=Knn.predict(x_test)
y_pred1
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
y_pred1=Knn.predict(x_test)
cm=confusion_matrix(y_test,y_pred1)
print(cm)
# Out:
# [[1552   71]
#  [ 228  149]]

# %%
cmd = ConfusionMatrixDisplay(cm)
cmd.plot()

# %%
#accuracy score
from sklearn.metrics import accuracy_score
score1=accuracy_score(y_test,y_pred1)
score1
# Out:
# 0.8505

# %%
#classification report
from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91      1623
#            1       0.68      0.40      0.50       377
#
#     accuracy                           0.85      2000
#    macro avg       0.77      0.68      0.71      2000
# weighted avg       0.84      0.85      0.83      2000

# %%
#overfit,underfit,goodfit
training_score1 = Knn.score(x_train,y_train)
training_score1
# Out:
# 0.87725

# %%
testing_score1 = Knn.score(x_test,y_test)
testing_score1
# Out:
# 0.8505

# %% [markdown]
# 2)Logisitic Regression

# %%
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred2=log.predict(x_test)
y_pred2
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
y_pred2=log.predict(x_test)
cm=confusion_matrix(y_test,y_pred2)
print(cm)
# Out:
# [[1569   54]
#  [ 313   64]]

# %%
cmd = ConfusionMatrixDisplay(cm)
cmd.plot()

# %%
#accuracy score
from sklearn.metrics import accuracy_score
score1=accuracy_score(y_test,y_pred2)
score1
# Out:
# 0.8165

# %%
#classification report
from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.90      1623
#            1       0.54      0.17      0.26       377
#
#     accuracy                           0.82      2000
#    macro avg       0.69      0.57      0.58      2000
# weighted avg       0.78      0.82      0.78      2000

# %%
training_score2 = log.score(x_train,y_train)
training_score2
# Out:
# 0.805375

# %%
testing_score2 = log.score(x_test,y_test)
testing_score2
# Out:
# 0.8165

# %% [markdown]
# 3)SVM-Support Vector Machine Algorithm

# %%
from sklearn.svm import SVC
sv_model=SVC()
sv_model.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred3 = sv_model.predict(x_test)
y_pred3
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
y_pred3=sv_model.predict(x_test)
cm=confusion_matrix(y_test,y_pred3)
print(cm)
# Out:
# [[1584   39]
#  [ 228  149]]

# %%
cmd = ConfusionMatrixDisplay(cm)
cmd.plot()

# %%
#accuracy score
from sklearn.metrics import accuracy_score
score1=accuracy_score(y_test,y_pred3)
score1
# Out:
# 0.8665

# %%
#classification report
from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92      1623
#            1       0.79      0.40      0.53       377
#
#     accuracy                           0.87      2000
#    macro avg       0.83      0.69      0.72      2000
# weighted avg       0.86      0.87      0.85      2000

# %%
training_score3 = sv_model.score(x_train,y_train)
training_score3
# Out:
# 0.860375

# %%
testing_score3 = sv_model.score(x_test,y_test)
testing_score3
# Out:
# 0.8665

# %% [markdown]
# 4)Decision TreeClassifier

# %%
from sklearn import tree
dt= tree.DecisionTreeClassifier()

dt = tree.DecisionTreeClassifier(max_depth=4,criterion='entropy')

dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
y_pred4 = dt.predict(x_test)
y_pred4
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
y_pred4=dt.predict(x_test)
cm=confusion_matrix(y_test,y_pred4)
print(cm)
# Out:
# [[1558   65]
#  [ 232  145]]

# %%
cmd = ConfusionMatrixDisplay(cm)
cmd.plot()

# %%
#accuracy score
from sklearn.metrics import accuracy_score
score1 = accuracy_score(y_test,y_pred4)
score1
# Out:
# 0.8515

# %%
#classification report
from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91      1623
#            1       0.69      0.38      0.49       377
#
#     accuracy                           0.85      2000
#    macro avg       0.78      0.67      0.70      2000
# weighted avg       0.84      0.85      0.83      2000

# %%
training_score4 = dt.score(x_train,y_train)
training_score4
# Out:
# 0.85125

# %%
testing_score4 = dt.score(x_test,y_test)
testing_score4
# Out:
# 0.8515

# %% [markdown]
# 5)NAIVE BAYES : GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB
bayes_model = GaussianNB()
bayes_model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred5=bayes_model.predict(x_test)
y_pred5
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
y_pred5=bayes_model.predict(x_test)
cm=confusion_matrix(y_test,y_pred5)
print(cm)
# Out:
# [[1581   42]
#  [ 278   99]]

# %%
cmd = ConfusionMatrixDisplay(cm)
cmd.plot()

# %%
#accuracy score
from sklearn.metrics import accuracy_score
score1 = accuracy_score(y_test,y_pred5)
score1
# Out:
# 0.84

# %%
#classification report
from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred5))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91      1623
#            1       0.70      0.26      0.38       377
#
#     accuracy                           0.84      2000
#    macro avg       0.78      0.62      0.65      2000
# weighted avg       0.82      0.84      0.81      2000

# %%
training_score5 = bayes_model.score(x_train,y_train)
training_score5
# Out:
# 0.824875

# %%
testing_score5 = bayes_model.score(x_test,y_test)
testing_score5
# Out:
# 0.84

# %% [markdown]
# 6)NAIVE BAYES : BernoulliNB

# %%
from sklearn.naive_bayes import BernoulliNB
bayes_model1 = BernoulliNB()
bayes_model1.fit(x_train,y_train)
# Out:
# BernoulliNB()

# %%
y_pred6 = bayes_model1.predict(x_test)
y_pred6
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
y_pred6=bayes_model1.predict(x_test)
cm=confusion_matrix(y_test,y_pred6)
print(cm)
# Out:
# [[1546   77]
#  [ 280   97]]

# %%
cmd = ConfusionMatrixDisplay(cm)
cmd.plot()

# %%
#accuracy score
from sklearn.metrics import accuracy_score
score1 = accuracy_score(y_test,y_pred6)
score1
# Out:
# 0.8215

# %%
#classification report
from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred6))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90      1623
#            1       0.56      0.26      0.35       377
#
#     accuracy                           0.82      2000
#    macro avg       0.70      0.60      0.62      2000
# weighted avg       0.79      0.82      0.79      2000

# %%
training_score6 = bayes_model1.score(x_train,y_train)
training_score6
# Out:
# 0.805125

# %%
testing_score6 = bayes_model1.score(x_test,y_test)
testing_score6
# Out:
# 0.8215

# %% [markdown]
# 7) Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier()
rf_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred7 = rf_model.predict(x_test)
y_pred7
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
y_pred7=rf_model.predict(x_test)
cm=confusion_matrix(y_test,y_pred7)
print(cm)
# Out:
# [[1569   54]
#  [ 203  174]]

# %%
cmd = ConfusionMatrixDisplay(cm)
cmd.plot()

# %%
#accuracy score
from sklearn.metrics import accuracy_score
score1 = accuracy_score(y_test,y_pred7)
score1
# Out:
# 0.8715

# %%
#classification report
from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred7))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.92      1623
#            1       0.76      0.46      0.58       377
#
#     accuracy                           0.87      2000
#    macro avg       0.82      0.71      0.75      2000
# weighted avg       0.86      0.87      0.86      2000

# %%
training_score7 = rf_model.score(x_train,y_train)
training_score7
# Out:
# 1.0

# %%
testing_score7 = rf_model.score(x_test,y_test)
testing_score7
# Out:
# 0.8715

# %% [markdown]
# 8)Ada Boost-Adaptive Boosting

# %%
from sklearn.ensemble import AdaBoostClassifier
ad_model= AdaBoostClassifier(n_estimators=10,learning_rate=1.0)
ad_model.fit(x_train,y_train)
# Out:
# AdaBoostClassifier(n_estimators=10)

# %%
y_pred8 =ad_model.predict(x_test)
y_pred8
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
y_pred8=ad_model.predict(x_test)
cm=confusion_matrix(y_test,y_pred8)
print(cm)
# Out:
# [[1550   73]
#  [ 211  166]]

# %%
cmd = ConfusionMatrixDisplay(cm)
cmd.plot()

# %%
#accuracy score
from sklearn.metrics import accuracy_score
score1 = accuracy_score(y_test,y_pred8)
score1
# Out:
# 0.858

# %%
#classification report
from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred8))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92      1623
#            1       0.69      0.44      0.54       377
#
#     accuracy                           0.86      2000
#    macro avg       0.79      0.70      0.73      2000
# weighted avg       0.85      0.86      0.84      2000

# %%
training_score8 = ad_model.score(x_train,y_train)
training_score8
# Out:
# 0.852

# %%
testing_score8 = ad_model.score(x_test,y_test)
testing_score8
# Out:
# 0.858

# %%
final_df=pd.DataFrame({'Models' :['Knn','LR','SVC','DT','NB-G','NB-B','RF','AB'],
                  'accuracy_score':[accuracy_score(y_test,y_pred1),
                                     accuracy_score(y_test,y_pred2),
                                     accuracy_score(y_test,y_pred3),
                                     accuracy_score(y_test,y_pred4),
                                     accuracy_score(y_test,y_pred5),
                                     accuracy_score(y_test,y_pred6),
                                     accuracy_score(y_test,y_pred7),
                                     accuracy_score(y_test,y_pred8)]})
print(final_df)
# Out:
#   Models  accuracy_score
# 0    Knn          0.8505
# 1     LR          0.8165
# 2    SVC          0.8665
# 3     DT          0.8515
# 4   NB-G          0.8400
# 5   NB-B          0.8215
# 6     RF          0.8715
# 7     AB          0.8580

# %%
sns.barplot(x='Models',y='accuracy_score',data=final_df,palette='dark')
# Out:
# <ipython-input-100-76937eee3c24>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Models',y='accuracy_score',data=final_df,palette='dark')
# <Axes: xlabel='Models', ylabel='accuracy_score'>

# %% [markdown]
# CONCLUSION
#
# From the performance evaluation RandomForest has highest accuracy and also using other performance accuracy score and precision score is high for RandomForest.so we choose RandomForest is the best model.

# %%
df["Exited"].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %% [markdown]
# Handling Imbalanced data into balanced using SMOTE

# %%
#SMOTE
from imblearn.over_sampling import SMOTE
x_res,y_res=SMOTE().fit_resample(x,y)

# %%
y_res.value_counts()
# Out:
# Exited
# 1    7963
# 0    7963
# Name: count, dtype: int64

# %%
#train test split
from sklearn.model_selection import train_test_split
x_train1,x_test1,y_train1,y_test1 = train_test_split(x_res,y_res,test_size=0.2,random_state=20)

# %%
#Standardization
from sklearn.preprocessing import StandardScaler
sc1=StandardScaler()

x_train1=sc1.fit_transform(x_train1)
x_test1 = sc.fit_transform(x_test1)

# %%
import pickle
filename='scaler1.sav'
pickle.dump(sc1,open(filename,'wb'))

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model1 = RandomForestClassifier(n_estimators=100,criterion='gini',max_depth=5,max_features=5)
rf_model1.fit(x_train1,y_train1)
# Out:
# RandomForestClassifier(max_depth=5, max_features=5)

# %%
import pickle
filename='model1.sav'
pickle.dump(rf_model1,open(filename,'wb')) #wb-write binary

# %%
y_pred9 =rf_model1.predict(x_test1)
y_pred9
# Out:
# array([0, 1, 0, ..., 1, 0, 0])

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
y_pred9==rf_model1.predict(x_test1)
cm=confusion_matrix(y_test1,y_pred9)
print(cm)
# Out:
# [[1301  268]
#  [ 344 1273]]

# %%
cmd = ConfusionMatrixDisplay(cm)
cmd.plot()

# %%
training_score9 =rf_model1.score(x_train1,y_train1)
training_score9
# Out:
# 0.8172684458398745

# %%
testing_score9 =rf_model1.score(x_test1,y_test1)
testing_score9
# Out:
# 0.807909604519774

# %%
#accuracy score
from sklearn.metrics import accuracy_score
score1 = accuracy_score(y_test1,y_pred9)
score1
# Out:
# 0.807909604519774

# %%
#classification report
from sklearn.metrics import classification_report

print(classification_report(y_test1,y_pred9))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81      1569
#            1       0.83      0.79      0.81      1617
#
#     accuracy                           0.81      3186
#    macro avg       0.81      0.81      0.81      3186
# weighted avg       0.81      0.81      0.81      3186

# %%
rf_model1.predict([[600,1,0,42,2,56869.61,1,0,1,9200.52]])
# Out:
# array([0])

# %% [markdown]
# OBSERVATION
#
# Imbalanced data has the highest accuracy score when compared to the balanced data.

# %% [markdown]
# HyperParameter Tunning
#
# Applying Hyper parameter Tuning

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint as sp_randint

rfc= RandomForestClassifier()

# %%
param_dist = {"n_estimators": sp_randint(5,200),"max_depth": [5, None],
              "max_features": sp_randint(1, 11),"min_samples_split": sp_randint(2, 11),
              "min_samples_leaf": sp_randint(1, 11),"bootstrap": [True, False],
              "criterion": ["gini", "entropy"]}

# %%
randomCV = RandomizedSearchCV(rfc,param_distributions=param_dist,cv=10)
randomCV.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=10, estimator=RandomForestClassifier(),
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['gini', 'entropy'],
#                                         'max_depth': [5, None],
#                                         'max_features': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x79169a677130>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x79169a675e40>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x79169a675b70>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x79169a675060>})

# %%
rf_model2 = RandomForestClassifier(bootstrap=True,criterion='entropy',max_depth=None,max_features=6,min_samples_leaf=10,min_samples_split=2,n_estimators=100)
rf_model2.fit(x_train,y_train)

y_pred = rf_model2.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
training_score = rf_model2.score(x_train,y_train)
training_score
# Out:
# 0.887125

# %%
testing_score = rf_model2.score(x_test,y_test)
testing_score
# Out:
# 0.868

# %%
#accuracy score
from sklearn.metrics import accuracy_score
score1 = accuracy_score(y_test,y_pred)
score1
# Out:
# 0.868

# %%
#classification report
from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92      1623
#            1       0.75      0.45      0.56       377
#
#     accuracy                           0.87      2000
#    macro avg       0.82      0.71      0.74      2000
# weighted avg       0.86      0.87      0.85      2000

# %% [markdown]
# Predicting New data point

# %%
rf_model2.predict([[700,1,0,42,2,56869.61,2,0,1,9200.52]])
# Out:
# array([1])

# %% [markdown]
# CONCLUSION
#
# From this we can understand by applying Hyperparameter Tunning we found the best hyperparameter and the built best model.
